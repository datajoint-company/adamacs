# %% [markdown]
# ### Datajoint Local troubleshooting notebook

# %%
from adamacs import subject, surgery, session, behavior, imaging, scan
from adamacs import utility
import datajoint as dj

# %%
dj.config
dj.conn()
# Out:
# Connecting root@172.26.128.53:3306
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~\anaconda3\envs\datajoint\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     612                         try:
# --> 613                             sock = socket.create_connection(
#     614                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# ~\anaconda3\envs\datajoint\lib\socket.py in create_connection(address, timeout, source_address)
#     807         try:
# --> 808             raise err
#     809         finally:
#
# ~\anaconda3\envs\datajoint\lib\socket.py in create_connection(address, timeout, source_address)
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1088/1498653890.py in <module>
#       1 dj.config
# ----> 2 dj.conn()
#
# ~\anaconda3\envs\datajoint\lib\site-packages\datajoint\connection.py in conn(host, user, password, init_fun, reset, use_tls)
#     117         init_fun = init_fun if init_fun is not None else config['connection.init_function']
#     118         use_tls = use_tls if use_tls is not None else config['database.use_tls']
# --> 119         conn.connection = Connection(host, user, password, None, init_fun, use_tls)
#     120     return conn.connection
#     121
#
# ~\anaconda3\envs\datajoint\lib\site-packages\datajoint\connection.py in __init__(self, host, user, password, port, init_fun, use_tls)
#     176         self._conn = None
#     177         self._query_cache = None
# --> 178         connect_host_hook(self)
#     179         if self.is_connected:
#     180             logger.info("Connected {user}@{host}:{port}".format(**self.conn_info))
#
# ~\anaconda3\envs\datajoint\lib\site-packages\datajoint\connection.py in connect_host_hook(connection_obj)
#      43                 "Connection plugin '{}' not found.".format(plugin_name))
#      44     else:
# ---> 45         connection_obj.connect()
#      46
#      47
#
# ~\anaconda3\envs\datajoint\lib\site-packages\datajoint\connection.py in connect(self)
#     199             warnings.filterwarnings('ignore', '.*deprecated.*')
#     200             try:
# --> 201                 self._conn = client.connect(
#     202                     init_command=self.init_fun,
#     203                     sql_mode="NO_ZERO_DATE,NO_ZERO_IN_DATE,ERROR_FOR_DIVISION_BY_ZERO,"
#
# ~\anaconda3\envs\datajoint\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351             self._sock = None
#     352         else:
# --> 353             self.connect()
#     354
#     355     def __enter__(self):
#
# ~\anaconda3\envs\datajoint\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     662                 if DEBUG:
#     663                     print(exc.traceback)
# --> 664                 raise exc
#     665
#     666             # If e is neither DatabaseError or IOError, It's a bug.
#
# OperationalError: (2003, "Can't connect to MySQL server on '172.26.128.53' (timed out)")

# %% [markdown]
# Local datajoint database setup: https://tutorials.datajoint.io/setting-up/local-database.html

# %%
# conda env create -f environment.yml
# docker run -p 3306:3306 -e MYSQL_ROOT_PASSWORD=tutorial datajoint/mysql

# %%
# Setup Local configuration
dj.config['database.host'] = '127.0.0.1'
dj.config['database.user'] = 'root'
dj.config['database.password'] = 'tutorial'
dj.conn()
# Out:
# Connecting root@127.0.0.1:3306
# DataJoint connection (connected) root@127.0.0.1:3306

# %% [markdown]
# ### Create schema and tables

# %%
utility.activate_many(name='tutorial')

# %%
dj.ERD(subject.schema)

# %% [markdown]
# ### Insert Animal Data

# %%
# Insert Laboratories
lab = subject.Lab()
lab_data = [
    ('Rose',
    'AG Rose, Circuit mechanisms of behavior',
    'Institute for Experimental Epileptology and Cognition Research',
    'Venusberg-Campus 1, 53127, Bonn',
    'CET'),
    ('Gm',
    'AG Gründemann, Informationsverarbeitung neuronaler Schaltkreise',
    'DZNE',
    'Venusberg-Campus 1, 53127, Bonn',
    'CET'),
    ('Fm',
    'AG Fuhrmann, Neuroimmunologie und Bildgebung',
    'DZNE',
    'Venusberg-Campus 1, 53127, Bonn',
    'CET'),
    ('Beck',
    'AG Beck, Experimental Epileptology and Cognition Research',
    'Institute for Experimental Epileptology and Cognition Research',
    'Venusberg-Campus 1, 53127, Bonn',
    'CET')
]

lab.insert(lab_data, skip_duplicates=True)
lab
# Out:
# *lab     lab_name       institution    address        time_zone
# +------+ +------------+ +------------+ +------------+ +-----------+
# Beck     AG Beck, Exper Institute for  Venusberg-Camp CET
# Fm       AG Fuhrmann, N DZNE           Venusberg-Camp CET
# Gm       AG Gründemann, DZNE           Venusberg-Camp CET
# Rose     AG Rose, Circu Institute for  Venusberg-Camp CET
#  (Total: 4)

# %%
# Insert line
line = subject.Line()
line_data = [("SST-IRES-Cre", "The SST-IRES-Cre Mouse Line is Daniels favorite mouse line", "wt/tg", True),
             ("VGluT3-Cre", "", "tg/tg", True),
             ("VGluT2-Cre", "", "", True),
             ("SST-IRES-Cre/VGluT3-Cre", "", "", True)
             ]
line.insert(line_data, skip_duplicates=True)
line
# Out:
# *line          line_descripti target_genotyp is_active
# +------------+ +------------+ +------------+ +-----------+
# SST-IRES-Cre   The SST-IRES-C wt/tg          1
# SST-IRES-Cre/V                               1
# VGluT2-Cre                                   1
# VGluT3-Cre                    tg/tg          1
#  (Total: 4)

# %%
# Define mouse line mutations
mutation = subject.Mutation()
mutation_data = [("SST-IRES-Cre", "Ssttm2.1(cre)Zjh", "The Sst-IRES-Cre knock-in allele (or SOM-IRES-Cre) was designed by Dr. Z. Josh Huang (Cold Spring Harbor Laboratory). A targeting vector was designed to insert an internal ribosome entry site (IRES), a Cre recombinase sequence, a polyA sequence, and an frt-flanked neo cassette into the 3' untranslated region (after the translational termination site) of the somatostatin locus (Sst or SOM) on chromosome 16."),
                 ("VGluT3-Cre", "Tg(Slc17a8-icre)1Edw", "The C57BL/6 mouse bacterial artificial chromosome (BAC) RP24-88H21, containing the entire Slc17a8 locus only, was modified by targeting a codon optimized cre recombinase (iCre), followed by an SV40 polyA signal, into the ATG start site of the Slc17a8 locus. The modified BAC was microinjected into fertilized FVB/N oocytes and transgenic founders were obtained. "),
                 ("VGluT2-Cre", "Slc17a6tm2(cre)Lowl/J", ''),
                 ("SST-IRES-Cre/VGluT3-Cre", "Ssttm2.1(cre)Zjh", ''),
                 ("SST-IRES-Cre/VGluT3-Cre", "Tg(Slc17a8-icre)1Edw", '')
                ]
mutation.insert(mutation_data, skip_duplicates=True)
mutation
# Out:
# *line          *mutation      description
# +------------+ +------------+ +------------+
# SST-IRES-Cre   Ssttm2.1(cre)Z The Sst-IRES-C
# SST-IRES-Cre/V Ssttm2.1(cre)Z
# SST-IRES-Cre/V Tg(Slc17a8-icr
# VGluT2-Cre     Slc17a6tm2(cre
# VGluT3-Cre     Tg(Slc17a8-icr The C57BL/6 mo
#  (Total: 5)

# %%
# Insert user
user = subject.User()
user.insert1(("dmk",
             "Rose"))
user
# Out:
# *user    lab
# +------+ +------+
# dmk      Rose
#  (Total: 1)

# %%
# Insert Protocol
protocol = subject.Protocol()
protocol.insert1(("LANUF2",
                 "Basic Animal Protocol"))
protocol
# Out:
# *protocol    protocol_descr
# +----------+ +------------+
# LANUF2       Basic Animal P
#  (Total: 1)

# %%
# Insert Project
project = subject.Project()
project.insert1(("TEC",
                 "FM"))
project
# Out:
# *project    project_descri
# +---------+ +------------+
# TEC         FM
#  (Total: 1)

# %%
# Insert Subjects
animal = subject.Subject()
subject_data = [
    ('ROS-0001', 'Rose', 'G114', 'M', '2020-08-13', '', 'SST-IRES-Cre', 'dmk', "TEC", "LANUF2"),
    ('ROS-0002', 'Beck', 'G110', 'M', '2021-08-13', '', 'SST-IRES-Cre', 'dmk', "TEC", "LANUF2"),
    ('ROS-0003', 'Rose', 'G111', 'M', '2020-08-13', '', 'SST-IRES-Cre/VGluT3-Cre', 'dmk', "TEC", "LANUF2")
]
animal.insert(subject_data, skip_duplicates=True)
animal
# Out:
# *subject     lab      earmark     sex     birth_date     subject_descri line           user     project     protocol
# +----------+ +------+ +---------+ +-----+ +------------+ +------------+ +------------+ +------+ +---------+ +----------+
# ROS-0001     Rose     G114        M       2020-08-13                    SST-IRES-Cre   dmk      TEC         LANUF2
# ROS-0002     Beck     G110        M       2021-08-13                    SST-IRES-Cre   dmk      TEC         LANUF2
# ROS-0003     Rose     G111        M       2020-08-13                    SST-IRES-Cre/V dmk      TEC         LANUF2
#  (Total: 3)

# %%
# Insert subject genotype
genotype = subject.SubjectGenotype()
genotype_data = [
    ('ROS-0001', 'SST-IRES-Cre', 'Ssttm2.1(cre)Zjh', 'wt/tg'),
    ('ROS-0002', 'SST-IRES-Cre', 'Ssttm2.1(cre)Zjh', 'wt/wt'),
    ('ROS-0003', 'SST-IRES-Cre/VGluT3-Cre', 'Ssttm2.1(cre)Zjh', 'wt/tg'),
    ('ROS-0003', 'SST-IRES-Cre/VGluT3-Cre', 'Tg(Slc17a8-icre)1Edw', 'wt/wt')
]
genotype.insert(genotype_data, skip_duplicates=True)
genotype
# Out:
# *subject     *line          *mutation      genotype
# +----------+ +------------+ +------------+ +----------+
# ROS-0001     SST-IRES-Cre   Ssttm2.1(cre)Z wt/tg
# ROS-0002     SST-IRES-Cre   Ssttm2.1(cre)Z wt/wt
# ROS-0003     SST-IRES-Cre/V Ssttm2.1(cre)Z wt/tg
# ROS-0003     SST-IRES-Cre/V Tg(Slc17a8-icr wt/wt
#  (Total: 4)

# %%
# Record subject death
animal = subject.SubjectDeath()
animal.insert1(('ROS-0001', '2021-10-10', 'Perfusion'))
animal
# Out:
# ---------------------------------------------------------------------------
# DuplicateError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14432/2397721020.py in <module>
#       1 # Record subject death
#       2 animal = subject.SubjectDeath()
# ----> 3 animal.insert1(('ROS-0001', '2021-10-10', 'Perfusion'))
#       4 animal
#
# ~\anaconda3\envs\datajoint\lib\site-packages\datajoint\table.py in insert1(self, row, **kwargs)
#     264         For kwargs, see insert()
#     265         """
# --> 266         self.insert((row,), **kwargs)
#     267
#     268     def insert(self, rows, replace=False, skip_duplicates=False, ignore_extra_fields=False, allow_direct_insert=None):
#
# ~\anaconda3\envs\datajoint\lib\site-packages\datajoint\table.py in insert(self, rows, replace, skip_duplicates, ignore_extra_fields, allow_direct_insert)
#     335                     'To ignore extra fields in insert, set ignore_extra_fields=True')
#     336             except DuplicateError as err:
# --> 337                 raise err.suggest(
#     338                     'To ignore duplicate entries in insert, set skip_duplicates=True')
#     339
#
# DuplicateError: ("Duplicate entry 'ROS-0001' for key 'PRIMARY'", 'To ignore duplicate entries in insert, set skip_duplicates=True')

# %% [markdown]
# ### Insert Surgery Data

# %%
# Create dummy records for our viruses
virus = surgery.Virus()
virus_data = [
    ('GCamp8s', 'AAV1', 'pGP-AAV-syn-jGCaMP8s-WPRE (AAV1)'),
    ('jRGECO1a', 'AAV1', 'pAAV.CAG.Flex.NES-jRGECO1a.WPRE.SV40 (AAV1)')
]
virus.insert(virus_data, skip_duplicates=True)
virus
# Out:
# *name        *serotype    long_name
# +----------+ +----------+ +------------+
# GCamp8s      AAV1         pGP-AAV-syn-jG
# jRGECO1a     AAV1         pAAV.CAG.Flex.
#  (Total: 2)

# %%
# Create dummy anesthesia
anesthesia = surgery.Anesthesia()
anesthesia_data = [
    ('FMM', 'Fenanyl/Midalozam/Medetomidin'),
]
anesthesia.insert(anesthesia_data, skip_duplicates=True)
anesthesia
# Out:
# *anesthesia    long_name
# +------------+ +------------+
# FMM            Fenanyl/Midalo
#  (Total: 1)

# %%
# Create dummy anesthesia
analgesia = surgery.Analgesia()
analgesia_data = [
    ('Ketoprofen', 'Ketoprofen'),
]
analgesia.insert(analgesia_data, skip_duplicates=True)
analgesia
# Out:
# *analgesia     long_name
# +------------+ +------------+
# Ketoprofen     Ketoprofen
#  (Total: 1)

# %%
# Create dummy anesthesia
antagonist = surgery.Antagonist()
antagonist_data = [
    ('NFA', 'Naloxon/Flumayenil/Atipamezol'),
]
antagonist.insert(antagonist_data, skip_duplicates=True)
antagonist
# Out:
# *antagonist    long_name
# +------------+ +------------+
# NFA            Naloxon/Flumay
#  (Total: 1)

# %%
# Create dummy coordinates
coordinates = surgery.Coordinates()
coordinates_data = [
    ('CA3VR', -0.23, -0.17, -0.24, 'Injection into ventral CA3 in right hemisphere.'),
    ('CA3VL', -0.23, 0.17, -0.24, 'Injection into ventral CA3 in right hemisphere.')
]
coordinates.insert(coordinates_data, skip_duplicates=True)
coordinates
# Out:
# *coordinates   x_coordinate   y_coordinate   z_coordinate   description
# +------------+ +------------+ +------------+ +------------+ +------------+
# CA3VL          -0.23          0.17           -0.24          Injection into
# CA3VR          -0.23          -0.17          -0.24          Injection into
#  (Total: 2)

# %%
# Perform a surgery with two viral injections followed by a cranial window
sur = surgery.Surgery()
# Add the surgery
sur.insert1(('ROS-0001', 'Rose', '21-10-12', 23, 'dmk', 'FMM', '12:40', 500, 'NFA', '13:20', 500))

# Add the viral injections
vi = surgery.ViralInjection()
vi.insert1(('ROS-0001', 'Rose', '21-10-12', 'GCamp8s', 'AAV1', 'CA3VR', '13:30', 500))  # Inject GCamp8s into the right ventral CA3
vi.insert1(('ROS-0001', 'Rose', '21-10-12', 'jRGECO1a', 'AAV1', 'CA3VL', '14:00', 500))  # Inject JRGECO into the right ventral CA3

# Add cranial window
cw = surgery.CranialWindow()
cw.insert1(('ROS-0001', 'Rose', '21-10-12', '14:30'))  # Apply cranial window

# Give analgesia
ag = surgery.AnalgesiaSubject()
ag.insert1(('Ketoprofen', 'ROS-0001', 'Rose', '21-10-12 12:55'))  # Analgesia before surgery
ag.insert1(('Ketoprofen', 'ROS-0001', 'Rose', '21-10-12 15:00'))  # Analgesia after surgery
ag.insert1(('Ketoprofen', 'ROS-0001', 'Rose', '21-10-13 15:00'))  # Analgesia day after surgery
ag.insert1(('Ketoprofen', 'ROS-0001', 'Rose', '21-10-14 15:00'))  # Analgesia second day after surgery
ag.insert1(('Ketoprofen', 'ROS-0001', 'Rose', '21-10-15 15:00'))  # Analgesia third day after surgery
sur

# Add a surgery note
sn = surgery.SurgeryNote()
sn.insert1(('ROS-0001', 'Rose', '21-10-12',
            'The surgery went exceeedingly well. Absolutely nothing went wrong. It could not have gone better and I am' +
            'extemely happy with the way it went. The mouse woke up and is in excellent condition. I hope all my surgeries' +
            'will be like this one.'))
# Out:
# ---------------------------------------------------------------------------
# DataJointError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14432/2686574098.py in <module>
#       2 sur = surgery.Surgery()
#       3 # Add the surgery
# ----> 4 sur.insert1(('ROS-0001', 'Rose', '21-10-12', 23, 'dmk', 'FMM', '12:40', 500, 'NFA', '13:20', 500))
#       5
#       6 # Add the viral injections
#
# ~\anaconda3\envs\datajoint\lib\site-packages\datajoint\table.py in insert1(self, row, **kwargs)
#     264         For kwargs, see insert()
#     265         """
# --> 266         self.insert((row,), **kwargs)
#     267
#     268     def insert(self, rows, replace=False, skip_duplicates=False, ignore_extra_fields=False, allow_direct_insert=None):
#
# ~\anaconda3\envs\datajoint\lib\site-packages\datajoint\table.py in insert(self, rows, replace, skip_duplicates, ignore_extra_fields, allow_direct_insert)
#     318
#     319         field_list = []  # collects the field list from first row (passed by reference)
# --> 320         rows = list(self.__make_row_to_insert(row, field_list, ignore_extra_fields) for row in rows)
#     321         if rows:
#     322             try:
#
# ~\anaconda3\envs\datajoint\lib\site-packages\datajoint\table.py in <genexpr>(.0)
#     318
#     319         field_list = []  # collects the field list from first row (passed by reference)
# --> 320         rows = list(self.__make_row_to_insert(row, field_list, ignore_extra_fields) for row in rows)
#     321         if rows:
#     322             try:
#
# ~\anaconda3\envs\datajoint\lib\site-packages\datajoint\table.py in __make_row_to_insert(self, row, field_list, ignore_extra_fields)
#     678             try:
#     679                 if len(row) != len(self.heading):
# --> 680                     raise DataJointError(
#     681                         'Invalid insert argument. Incorrect number of attributes: '
#     682                         '{given} given; {expected} expected'.format(
#
# DataJointError: Invalid insert argument. Incorrect number of attributes: 11 given; 10 expected

# %%
line = subject.Line()
line
sub = subject.Subject()
sub
# Out:
# *subject     lab      earmark     sex     birth_date     subject_descri line           user     project     protocol
# +----------+ +------+ +---------+ +-----+ +------------+ +------------+ +------------+ +------+ +---------+ +----------+
# ROS-0001     Rose     G114        M       2020-08-13                    SST-IRES-Cre   dmk      TEC         LANUF2
# ROS-0002     Beck     G110        M       2021-08-13                    SST-IRES-Cre   dmk      TEC         LANUF2
# ROS-0003     Rose     G111        M       2020-08-13                    SST-IRES-Cre/V dmk      TEC         LANUF2
#  (Total: 3)

# %%
cw
# Out:
# *subject     *lab     *date          time
# +----------+ +------+ +------------+ +----------+
# ROS-0001     Rose     2021-10-12     14:30:00
#  (Total: 1)

# %%
ag
# Out:
# *analgesia     *subject     *lab     *datetime
# +------------+ +----------+ +------+ +------------+
# Ketoprofen     ROS-0001     Rose     2021-10-12 12:
# Ketoprofen     ROS-0001     Rose     2021-10-12 15:
# Ketoprofen     ROS-0001     Rose     2021-10-13 15:
# Ketoprofen     ROS-0001     Rose     2021-10-14 15:
# Ketoprofen     ROS-0001     Rose     2021-10-15 15:
#  (Total: 5)

# %%
sn
# Out:
# *subject     *lab     *date          note
# +----------+ +------+ +------------+ +------------+
# ROS-0001     Rose     2021-10-12     The surgery we
#  (Total: 1)

# %%
animal
# Out:
# *subject     *lab     death_date     cause
# +----------+ +------+ +------------+ +-----------+
# ROS-0001     Rose     2021-10-10     Perfusion
#  (Total: 1)
