# %% [markdown]
# # Demonstrate the RSpace API

# %%
# Connect to server if 'message': 'OK' it worked
from adamacs import rspace
client = rspace.connect()
client.get_status()
# Out:
# {'message': 'OK', 'rspaceVersion': '1.69.53'}

# %%
example_document = client.get_document('SD37310')

# %%
example_document.keys()
# Out:
# dict_keys(['id', 'globalId', 'name', 'created', 'lastModified', 'parentFolderId', 'signed', 'tags', 'form', 'owner', 'fields', '_links'])

# %%
example_document = client.get_documents()
example_document
# Out:
# {'totalHits': 16,
#  'pageNumber': 0,
#  'documents': [{'id': 37344,
#    'globalId': 'SD37344',
#    'name': 'ExampleSurgery',
#    'created': '2021-10-13T12:30:12.456Z',
#    'lastModified': '2021-10-13T12:37:59.694Z',
#    'parentFolderId': 37343,
#    'signed': False,
#    'tags': None,
#    'form': {'id': 983103,
#     'globalId': 'FM983103',
#     'stableId': '1634112426330null',
#     'version': 0,
#     'name': 'SurgeryFormExampleDMK',
#     'tags': '',
#     'formState': 'PUBLISHED',
#     'accessControl': {'ownerPermissionType': 'WRITE',
#      'groupPermissionType': 'READ',
#      'worldPermissionType': 'NONE'},
#     '_links': []},
#    'owner': {'id': 688165,
#     'username': 'muellerk',
#     'email': 'muellerk@uni-bonn.de',
#     'firstName': 'Daniel',
#     'lastName': 'Mueller-Komorowska',
#     'homeFolderId': 35044,
#     '_links': []},
#    '_links': [{'link': 'https://rspace.rhrz.uni-bonn.de/api/v1/documents/37344',
#      'rel': 'self'}]},
#   {'id': 37345,
# ...

# %%
client.get_documents('SurgeryFormExampleDMK and ')
# Out:
# {'totalHits': 4,
#  'pageNumber': 0,
#  'documents': [{'id': 37344,
#    'globalId': 'SD37344',
#    'name': 'ExampleSurgery',
#    'created': '2021-10-13T12:30:12.456Z',
#    'lastModified': '2021-10-13T12:37:59.694Z',
#    'parentFolderId': 37343,
#    'signed': False,
#    'tags': None,
#    'form': {'id': 983103,
#     'globalId': 'FM983103',
#     'stableId': '1634112426330null',
#     'version': 0,
#     'name': 'SurgeryFormExampleDMK',
#     'tags': '',
#     'formState': 'PUBLISHED',
#     'accessControl': {'ownerPermissionType': 'WRITE',
#      'groupPermissionType': 'READ',
#      'worldPermissionType': 'NONE'},
#     '_links': []},
#    'owner': {'id': 688165,
#     'username': 'muellerk',
#     'email': 'muellerk@uni-bonn.de',
#     'firstName': 'Daniel',
#     'lastName': 'Mueller-Komorowska',
#     'homeFolderId': 35044,
#     '_links': []},
#    '_links': [{'link': 'https://rspace.rhrz.uni-bonn.de/api/v1/documents/37344',
#      'rel': 'self'}]},
#   {'id': 37345,
# ...
