# %% [markdown]
# # Connect to the Database

# %%
import datajoint as dj
from adamacs.schemas import subject, surgery
from adamacs import utility
from element_session import session_with_id
from element_calcium_imaging import scan
from adamacs.ingest import session as isess
import getpass

"""If you are don't have your login information, contact the administrator."""
dj.config['database.host'] = '172.26.128.53'  # Put the server name between these apostrophe
dj.config['database.user'] = 'danielmk'  # Put your user name between these apostrophe
dj.config['database.password'] = getpass.getpass(prompt='Database password:')  # Put your password between these apostrophe
dj.conn()
utility.activate_many(name='tutorial_two')
sub, lab, protocol, line, mutation, user, project, subject_genotype, subject_death = (
    subject.Subject(), subject.Lab(), subject.Protocol(), subject.Line(), subject.Mutation(), subject.User(),
    subject.Project(), subject.SubjectGenotype(), subject.SubjectDeath()
    )
session_with_id.activate('tutorial', create_schema=True, create_tables=True,
             linking_module=subject)
scan.activate('tutorial', create_schema=True, create_tables=True,
             linking_module=session_with_id)
# Out:
# Database password:········
# Connecting danielmk@172.26.128.53:3306

# %%
isess.ingest_session_scan('sess9FB2LN5C')
# Out:
# [['scan9FB2LN5C']]
# ['DB_WEZ-8701_2022-03-18_scan9FB2LN5C_sess9FB2LN5C']
# c:\users\daniel\repos\adamacs\adamacs\ingest\session.py:70: UserWarning: Session row ('sess9FB2LN5C', 'WEZ-8701', '2022-03-18') already inserted. Skipped!
#   warnings.warn(f'Session row {session_key, subject, date} already inserted. Skipped!')
# c:\users\daniel\repos\adamacs\adamacs\ingest\session.py:75: UserWarning: SessionDirectory ('sess9FB2LN5C', 'C:\\datajoint', 'DB') already inserted. Skipped!
#   warnings.warn(f'SessionDirectory {session_key, session_path, user} already inserted. Skipped!')
# c:\users\daniel\repos\adamacs\adamacs\ingest\session.py:80: UserWarning: SessionUser ('sess9FB2LN5C', 'DB') already inserted. Skipped!
#   warnings.warn(f'SessionUser {session_key, user} already inserted. Skipped!')
# c:\users\daniel\repos\adamacs\adamacs\ingest\session.py:91: UserWarning: Scan scan9FB2LN5C already inserted. Skipped
#   warnings.warn(f'Scan {s} already inserted. Skipped')
# c:\users\daniel\repos\adamacs\adamacs\ingest\session.py:96: UserWarning: ScanLocation for scan9FB2LN5C already inserted. Skipped
#   warnings.warn(f"ScanLocation for {s} already inserted. Skipped")
# c:\users\daniel\repos\adamacs\adamacs\ingest\session.py:101: UserWarning: ScanPath for scan9FB2LN5C already inserted. Skipped.
#   warnings.warn(f"ScanPath for {s} already inserted. Skipped.")

# %%
scan.ScanInfo().make(key='scan9FB2LN5C')
# Out:
# <class 'str'> C:\datajoint\DB_WEZ-8701_2022-03-18_scan9FB2LN5C_sess9FB2LN5C\scan9FB2LN5C_DB_WEZ-8701_02027_00001.tif
# ---------------------------------------------------------------------------
# DuplicateError                            Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 scan.ScanInfo().make(key='scan9FB2LN5C')
#
# File c:\users\daniel\repos\element-calcium-imaging\element_calcium_imaging\scan.py:216, in ScanInfo.make(self, key)
#     213 else:
#     214     x_zero = y_zero = z_zero = 0
# --> 216 self.insert1(dict(session_id=session_id,
#     217                   scan_id=key,
#     218                   nfields=scan.num_fields,
#     219                   nchannels=scan.num_channels,
#     220                   nframes=scan.num_frames,
#     221                   ndepths=scan.num_scanning_depths,
#     222                   x=x_zero,
#     223                   y=y_zero,
#     224                   z=z_zero,
#     225                   fps=scan.fps,
#     226                   bidirectional=scan.is_bidirectional,
#     227                   usecs_per_line=scan.seconds_per_line * 1e6,
#     228                   fill_fraction=scan.temporal_fill_fraction,
#     229                   nrois=scan.num_rois if scan.is_multiROI else 0),
#     230              allow_direct_insert=True)
#     232 # Insert Field(s)
#     233 if scan.is_multiROI:
#
# File ~\anaconda3\envs\datajoint12\lib\site-packages\datajoint\table.py:325, in Table.insert1(self, row, **kwargs)
#     318 def insert1(self, row, **kwargs):
#     319     """
#     320     Insert one data record into the table. For ``kwargs``, see ``insert()``.
#     321
#     322     :param row: a numpy record, a dict-like object, or an ordered sequence to be inserted
#     323     as one row.
#     324     """
# --> 325     self.insert((row,), **kwargs)
#
# File ~\anaconda3\envs\datajoint12\lib\site-packages\datajoint\table.py:431, in Table.insert(self, rows, replace, skip_duplicates, ignore_extra_fields, allow_direct_insert)
#     427     raise err.suggest(
#     428         "To ignore extra fields in insert, set ignore_extra_fields=True"
#     429     )
#     430 except DuplicateError as err:
# --> 431     raise err.suggest(
#     432         "To ignore duplicate entries in insert, set skip_duplicates=True"
#     433     )
#
# DuplicateError: ("Duplicate entry 'sess9FB2LN5C-scan9FB2LN5C' for key 'PRIMARY'", 'To ignore duplicate entries in insert, set skip_duplicates=True')

# %%
key='scan9FB2LN5C'

# %%
query = (scan.Scan & f"scan_id = '{key}'").fetch1()
query
# Out:
# {'session_id': 'sess9FB2LN5C',
#  'scan_id': 'scan9FB2LN5C',
#  'scanner': 'Equipment',
#  'acq_software': 'ScanImage',
#  'scan_notes': ''}

# %%
scan.ScanInfo()
# Out:
# *session_id    *scan_id       nfields     nchannels     ndepths     nframes     nrois     x       y       z       fps         bidirectional  usecs_per_line fill_fraction
# +------------+ +------------+ +---------+ +-----------+ +---------+ +---------+ +-------+ +-----+ +-----+ +-----+ +---------+ +------------+ +------------+ +------------+
# sess9FB2LN5C   scan9FB2LN5C   1           2             1           5000        0         0.0     0.0     0.0     15.3846     1              250.0          0.712867
#  (Total: 1)

# %%
scan.ScanInfo.Field()
# Out:
# *session_id    *scan_id       *field_idx    px_height     px_width     um_height     um_width     field_x     field_y     field_z     delay_imag roi
# +------------+ +------------+ +-----------+ +-----------+ +----------+ +-----------+ +----------+ +---------+ +---------+ +---------+ +--------+ +------+
# sess9FB2LN5C   scan9FB2LN5C   0             256           256          202.5         202.5        0.0         0.0         0.0         =BLOB=     None
#  (Total: 1)

# %%
scan.ScanInfo.ScanFile()
# Out:
# *session_id    *scan_id       *file_path
# +------------+ +------------+ +------------+
# sess9FB2LN5C   scan9FB2LN5C   C:\datajoint\D
#  (Total: 1)

# %%
scan.ScanInfo()
# Out:
# *session_id    *scan_id       nfields     nchannels     ndepths     nframes     nrois     x       y       z       fps         bidirectional  usecs_per_line fill_fraction
# +------------+ +------------+ +---------+ +-----------+ +---------+ +---------+ +-------+ +-----+ +-----+ +-----+ +---------+ +------------+ +------------+ +------------+
# sess9FB2LN5C   scan9FB2LN5C   1           2             1           5000        0         0.0     0.0     0.0     15.3846     1              250.0          0.712867
#  (Total: 1)
