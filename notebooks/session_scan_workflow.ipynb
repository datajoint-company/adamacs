# %% [markdown]
# # Connect to the Database

# %%
import datajoint as dj
from adamacs.schemas import subject, surgery
from adamacs import utility
from element_session import session_with_id
from element_calcium_imaging import scan
from adamacs.ingest import session as isess

"""If you are don't have your login information, contact the administrator."""
dj.config['database.host'] = '172.26.128.53'  # Put the server name between these apostrophe
dj.config['database.user'] = 'danielmk'  # Put your user name between these apostrophe
dj.config['database.password'] = 'thor13Phoenix%'  # Put your password between these apostrophe
dj.conn()
utility.activate_many(name='tutorial')
sub, lab, protocol, line, mutation, user, project, subject_genotype, subject_death = (
    subject.Subject(), subject.Lab(), subject.Protocol(), subject.Line(), subject.Mutation(), subject.User(),
    subject.Project(), subject.SubjectGenotype(), subject.SubjectDeath()
    )
session_with_id.activate('tutorial', create_schema=True, create_tables=True,
             linking_module=subject)
scan.activate('tutorial', create_schema=True, create_tables=True,
             linking_module=session_with_id)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 import datajoint as dj
#       2 from adamacs.schemas import subject, surgery
# ----> 3 from adamacs import utility
#       4 from element_session import session_with_id
#       5 from element_calcium_imaging import scan
#
# File c:\users\daniel\repos\adamacs\adamacs\utility.py:6, in <module>
#       4 import json
#       5 import os
# ----> 6 from .schemas import subject, surgery, behavior
#       7 from element_session import session_with_id
#       8 from element_calcium_imaging import scan
#
# File c:\users\daniel\repos\adamacs\adamacs\schemas\behavior.py:9, in <module>
#       1 """Tables related to behavioral data.
#       2
#       3 During some recordings behavioral data is recorded.
#       4 This module organizes the different types of behavioral
#       5 raw data and relates them to the Recording.
#       6 """
#       8 import datajoint as dj
# ----> 9 from . import session
#      10 from .. import db_prefix
#      11 # db_prefix + 'behavior'
#
# ImportError: cannot import name 'session' from 'adamacs.schemas' (c:\users\daniel\repos\adamacs\adamacs\schemas\__init__.py)

# %%
isess.ingest_session_scan('sess9FB2LN5C')

# %%
scan.ScanInfo().make(key='scan9FB2LN5C')

# %%
key='scan9FB2LN5C'

# %%
query = (scan.Scan & f"scan_id = '{key}'").fetch1()
query
# Out:
# {'session_id': 'sess9FB2LN5C',
#  'scan_id': 'scan9FB2LN5C',
#  'scanner': 'Equipment',
#  'acq_software': 'ScanImage',
#  'scan_notes': ''}

# %%
scan.ScanInfo()
# Out:
# *session_id    *scan_id       nfields     nchannels     ndepths     nframes     nrois     x       y       z       fps         bidirectional  usecs_per_line fill_fraction
# +------------+ +------------+ +---------+ +-----------+ +---------+ +---------+ +-------+ +-----+ +-----+ +-----+ +---------+ +------------+ +------------+ +------------+
# sess9FB2LN5C   scan9FB2LN5C   1           2             1           5000        0         0.0     0.0     0.0     15.3846     1              250.0          0.712867
#  (Total: 1)

# %%
scan.ScanInfo.Field()
# Out:
# *session_id    *scan_id       *field_idx    px_height     px_width     um_height     um_width     field_x     field_y     field_z     delay_imag roi
# +------------+ +------------+ +-----------+ +-----------+ +----------+ +-----------+ +----------+ +---------+ +---------+ +---------+ +--------+ +------+
# sess9FB2LN5C   scan9FB2LN5C   0             256           256          202.5         202.5        0.0         0.0         0.0         =BLOB=     None
#  (Total: 1)

# %%
scan.ScanInfo.ScanFile()
# Out:
# *session_id    *scan_id       *file_path
# +------------+ +------------+ +------------+
# sess9FB2LN5C   scan9FB2LN5C   C:\datajoint\D
#  (Total: 1)
